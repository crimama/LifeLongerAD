# %%
import pandas as pd 
from glob import glob 
import os

# %%
noises = ['random_rotation','gaussian_blur','color_jitter']


def load_noise_results(noise_type):
    log_dir = f'/Volume/VAD/LifeLongerAD_cu121/results/ProxyCore/MVTecAD/{noise_type}-Continual_False-online_False/seed_2/results/main.csv'
    return pd.read_csv(log_dir)

# %%
df1 = load_noise_results('random_rotation')
df2 = load_noise_results('color_jitter')
df3 = load_noise_results('gaussian_blur')

# %%
df2.drop(columns='Unnamed: 0')
# Out:
#    GT_class_name  img_level_auroc  img_level_average_precision  \
# 0        capsule         0.980854                     0.995731
# 1     toothbrush         0.994444                     0.997777
# 2          screw         0.909818                     0.952239
# 3           grid         0.837928                     0.924179
# 4         carpet         0.942616                     0.984088
# 5          cable         0.990067                     0.993596
# 6         zipper         0.988708                     0.997118
# 7           wood         0.955263                     0.985498
# 8           tile         0.979076                     0.992636
# 9      metal_nut         0.991202                     0.998048
# 10    transistor         0.983750                     0.983459
# 11        bottle         1.000000                     1.000000
# 12       leather         0.960938                     0.982954
# 13          pill         0.927441                     0.984700
# ...
